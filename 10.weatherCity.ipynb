# %%
import requests
import json
city =['Hyderabad','Patna','Agartala','Kohima','Chandigarh','Ranchi','Thiruvananthapuram','Mumbai', 'Bhubaneswar', 'Chandigarh', 'Panaji', 'Gandhinagar', 'Dispur', 'Amaravati', 'Dehradun',
 'Shimla',
 'Bhopal',
 'Jaipur',
 'Aizawl',
 'Srinagar',
 'Kolkata',
 'Raipur',
 'Chennai',
 'Lucknow',
 'Gangtok',
 'Itanagar',
 'Bangalore',
 'Shillong',
 'Imphal']
temp=[]
weather=[]
API_KEY = "430e1571976c1d6c6df4111f96459659"
for i in city:
    req_link = "http://api.openweathermap.org/data/2.5/weather?q="+i+"&appid="+API_KEY
    jsonStr = requests.get(req_link)
    jsonDict =json.loads(jsonStr.text)
    try:
        temp.append(jsonDict["main"]["temp"])
        weather.append(jsonDict["weather"][0]["main"])
        print(".",end="")
    except:
        print("Error Occurred!!")
        break
print()
for i in range(0,len(city)):
    print("City Name: "+city[i])
    print("Temperature: "+str(temp[i]))
    print("Weather: "+str(weather[i]))
    print()
# Out:
# .............................
# City Name: Hyderabad
# Temperature: 300.66
# Weather: Haze
#
# City Name: Patna
# Temperature: 294.15
# Weather: Smoke
#
# City Name: Agartala
# Temperature: 298.15
# Weather: Haze
#
# City Name: Kohima
# Temperature: 294.15
# Weather: Haze
#
# City Name: Chandigarh
# Temperature: 290.525
# Weather: Clear
#
# City Name: Ranchi
# Temperature: 294.15
# Weather: Haze
#
# City Name: Thiruvananthapuram
# Temperature: 303.15
# Weather: Clouds
#
# City Name: Mumbai
# Temperature: 302.15
# Weather: Smoke
#
# City Name: Bhubaneswar
# Temperature: 300.15
# Weather: Haze
#
# City Name: Chandigarh
# Temperature: 290.525
# Weather: Clear
#
# City Name: Panaji
# Temperature: 305.15
# Weather: Haze
#
# City Name: Gandhinagar
# Temperature: 298.15
# Weather: Smoke
#
# City Name: Dispur
# Temperature: 293.99
# Weather: Haze
#
# City Name: Amaravati
# Temperature: 300.15
# Weather: Haze
#
# City Name: Dehradun
# Temperature: 285.375
# Weather: Clouds
#
# ...

# %%
#first plot
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.plot(temp,city,color="green",linestyle="dashed",linewidth=3,marker="o",markerfacecolor="blue",markersize=10)
plt.xlabel("Temperature in Kelvin(K)")
plt.ylabel("State Capitals of India")
plt.title("Temperature Variation By State Capital of India")
plt.show()
# Out:
# [300.66, 294.15, 298.15, 294.15, 290.525, 294.15, 303.15, 302.15, 300.15, 290.525, 305.15, 298.15, 293.99, 300.15, 285.375, 282.175, 294.15, 294.15, 295.15, 271.2, 297.15, 297.15, 303.15, 294.15, 270.725, 297.15, 299.67, 294.42, 292.15]

# %%
#second plot(Bar Plot)
plt.figure(figsize=(10,10))
plt.barh(city,temp)
print(city)
plt.show()
# Out:
# ['Hyderabad', 'Patna', 'Agartala', 'Kohima', 'Chandigarh', 'Ranchi', 'Thiruvananthapuram', 'Mumbai', 'Bhubaneswar', 'Chandigarh', 'Panaji', 'Gandhinagar', 'Dispur', 'Amaravati', 'Dehradun', 'Shimla', 'Bhopal', 'Jaipur', 'Aizawl', 'Srinagar', 'Kolkata', 'Raipur', 'Chennai', 'Lucknow', 'Gangtok', 'Itanagar', 'Bangalore', 'Shillong', 'Imphal']

# %%
#Scatter Plot(do it)

# %%
#Historgram
plt.hist(weather,color="green")
plt.title("Weather Cout")
plt.xlabel("Type Of Weather")
plt.ylabel("Count of Cities")
plt.xticks(rotation=45)
plt.show()

# %%
#Pie chart
print([weather.count(i) for i in sets])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-b4918189b89a> in <module>()
#       1 #Pie chart
# ----> 2 print([weather.count(i) for i in sets])
#
# NameError: name 'sets' is not defined
